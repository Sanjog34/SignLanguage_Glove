# %%
import pandas as pd

df=pd.read_csv("sensor_data_8flex_alphaNEP.csv")

# %%
df.head()
# Out:
#    idxUp  idxLow  midUp  midLow  ringUp  ringLow  thumb  pinky label
# 0    123      70    100     125      54       34      0     51    ka
# 1    121      68    100     124      54       34      0     52    ka
# 2    118      66     99     124      54       34      0     51    ka
# 3    114      65     99     124      50       34      0     51    ka
# 4    114      63     98     124      50       34      0     49    ka

# %%
df.count
# Out:
# <bound method DataFrame.count of       idxUp  idxLow  midUp  midLow  ringUp  ringLow  thumb  pinky label
# 0       123      70    100     125      54       34      0     51    ka
# 1       121      68    100     124      54       34      0     52    ka
# 2       118      66     99     124      54       34      0     51    ka
# 3       114      65     99     124      50       34      0     51    ka
# 4       114      63     98     124      50       34      0     49    ka
# ...     ...     ...    ...     ...     ...      ...    ...    ...   ...
# 3495      0       0      0       0       0        0     20     51  teen
# 3496      0       0      0       0       0        0     22     50  teen
# 3497      0       0      0       0       0        0     27     51  teen
# 3498      0       0      0       0       0        0     24     50  teen
# 3499      0       0      0       0       0        0     24     48  teen
#
# [3500 rows x 9 columns]>

# %%
ka_df = df[df["label"] == "ka"]
kha_df = df[df["label"] == "kha"]
ga_df = df[df["label"] == "ga"]
gha_df = df[df["label"] == "gha"]
ek_df = df[df["label"] == "ek"]
dui_df = df[df["label"] == "dui"]
tin_df = df[df["label"] == "teen"]

# %%
ka_df.count
# Out:
# <bound method DataFrame.count of      idxUp  idxLow  midUp  midLow  ringUp  ringLow  thumb  pinky label
# 0      123      70    100     125      54       34      0     51    ka
# 1      121      68    100     124      54       34      0     52    ka
# 2      118      66     99     124      54       34      0     51    ka
# 3      114      65     99     124      50       34      0     51    ka
# 4      114      63     98     124      50       34      0     49    ka
# ..     ...     ...    ...     ...     ...      ...    ...    ...   ...
# 495     87      40     90     118      48       30      0     52    ka
# 496     89      40     91     118      50       30      0     52    ka
# 497     89      40     91     118      50       30      0     52    ka
# 498     89      40     92     118      50       32      0     51    ka
# 499     87      40     92     118      50       30      0     49    ka
#
# [500 rows x 9 columns]>

# %%
features = ["idxUp","idxLow","midUp","midLow","ringUp","ringLow","thumb","pinky"]
ka_features = ka_df[features]
kha_features = kha_df[features]
ga_features = ga_df[features]
gha_features = gha_df[features]
ek_features = ek_df[features]
dui_features = dui_df[features]
tin_features = tin_df[features]

# %%
ka_features.head
# Out:
# <bound method NDFrame.head of      idxUp  idxLow  midUp  midLow  ringUp  ringLow  thumb  pinky
# 0      123      70    100     125      54       34      0     51
# 1      121      68    100     124      54       34      0     52
# 2      118      66     99     124      54       34      0     51
# 3      114      65     99     124      50       34      0     51
# 4      114      63     98     124      50       34      0     49
# ..     ...     ...    ...     ...     ...      ...    ...    ...
# 495     87      40     90     118      48       30      0     52
# 496     89      40     91     118      50       30      0     52
# 497     89      40     91     118      50       30      0     52
# 498     89      40     92     118      50       32      0     51
# 499     87      40     92     118      50       30      0     49
#
# [500 rows x 8 columns]>

# %%
corr_ka = ka_features.corr(method="pearson")
corr_kha = kha_features.corr(method="pearson")
corr_ga = ga_features.corr(method="pearson")
corr_gha = gha_features.corr(method="pearson")
corr_ek = ek_features.corr(method="pearson")
corr_dui = dui_features.corr(method="pearson")
corr_tin = tin_features.corr(method="pearson")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(corr_ka, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'ka'")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_kha, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'kha'")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_ga, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'ga'")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_gha, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'gha'")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_ek, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'ek'")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_dui, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'dui'")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_tin, annot=True, cmap="coolwarm", square=True)
plt.title("Correlation Matrix for Gesture 'tin'")
plt.show()
# Out:
# /home/sanjog/.local/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/sanjog/.local/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
